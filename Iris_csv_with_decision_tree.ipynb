# %% [markdown]
# <a href="https://colab.research.google.com/github/wallik2/Deploy-model-Iris.csv/blob/main/Iris_csv_with_decision_tree.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import data

# %%
# !pip install kora kaggle --quiet
# Out:
#      |████████████████████████████████| 57 kB 2.9 MB/s
#      |████████████████████████████████| 56 kB 3.9 MB/s

# %%
from kora import kaggle

print("If failed, download Kaggle API to your drive first \n try the following link : https://www.youtube.com/watch?v=gkEbaMgvLs8")
# Out:
# If failed, download Kaggle API to your drive first
#  try the following link : https://www.youtube.com/watch?v=gkEbaMgvLs8

# %%
kaggle.download('arshid/iris-flower-dataset')
# Out:
# ...
#   0% 0.00/0.99k [00:00<?, ?B/s]
# 100% 0.99k/0.99k [00:00<00:00, 2.05MB/s]

# %% [markdown]
# # data

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/IRIS.csv')

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# > **4 features**

# %%
print(f'# of rows before drop : {len(df)}')

df.dropna(inplace=True)

print(f'# of rows after drop : {len(df)}')
# Out:
# # of rows before drop : 150
# # of rows after drop : 150

# %%
from sklearn import tree
y = df.pop('species') 
X = df

clf = tree.DecisionTreeClassifier()
clf = clf.fit(X, y)

# %%
clf.score(X,y)
# Out:
# 1.0

# %%
clf.predict(X=[[5.1,3.5,1.4,0.2 ]])
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:446: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# array(['Iris-setosa'], dtype=object)

# %%
import pickle

pickle.dump(clf, open('model.pkl','wb'))
